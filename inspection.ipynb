# %%
import matplotlib.pyplot as plt
import repype.batch

# %%
batch = repype.batch.Batch()
batch.load('segmentation')
batch.tasks
# Out:
# {PosixPath('segmentation'): <Task "segmentation" 5bde8ec>,
#  PosixPath('segmentation/sigma=2'): <Task "segmentation/sigma=2" 4a0575f>}

# %%
task = batch.task('segmentation')
task_data = task.load()
task_data.keys()
# Out:
# dict_keys(['B2--W00026--P00001--Z00000--T00000--dapi.tif'])

# %%
pipeline_data = task_data['B2--W00026--P00001--Z00000--T00000--dapi.tif']
pipeline_data.keys()
# Out:
# dict_keys(['input_id', 'image', 'preprocessed_image', 'segmentation'])

# %%
plt.imshow(pipeline_data['segmentation'], 'gray')
